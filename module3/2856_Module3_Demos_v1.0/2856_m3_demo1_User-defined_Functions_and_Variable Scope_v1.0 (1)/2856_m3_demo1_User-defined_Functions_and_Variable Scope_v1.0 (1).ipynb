# %% [markdown]
# ##Demo 1 - User-defined Functions and Variable Scope
# ### The below codes demonstrates the usage of user-defined functions and variable scope

# %%
# Example 1
# Here we are defining a function and calling it. The function has print statement in the function body

def func_1():   # Function Header
    print('This is your first function')  # Function Body
func_1()   # Function call
# Out:
# This is your first function

# %%
# Example 2
# The concept of formal argument is shown below. Here the scope of local variable and global variable is demonstrated

def func_2(x):    # x is formal argument or parameter
    y=10      # y is a local variable whose scope lies within the function only
    print(x+y)
func_2(5) # 5 is the actual parameter. It is mandatory to pass this parameter
# Out:
# 15

# %%
# Example 3
# The return statement is shown below. The function is called in various ways.
def func_3(a,b):
    print('Hello Python')
    return a+b   # return statement terminates the execution of function and control goes back to the calling position
# Method 1
x=func_3(5,6)
print(x)

# Method 2
print(func_3(5,6))

# Method 3
print(func_3(eval(input('Enter 1st operand ')),eval(input('Enter 2nd operand '))))
# Out:
# Hello Python
# 11
# Hello Python
# 11
# Enter 1st operand 2
# Enter 2nd operand 3
# Hello Python
# 5

# %% [markdown]
# ## Can we have two return statements in a function?

# %%
# Example 4
# Two return statements are demonstrated here. we can have multiple return statements but only of that will execute and that will be the last thing to be 
#executed in that called function
def func_4(x):
    if(x%2==0):
        return 'even'
    return 'odd'
func_4(10)
# Out:
# 'even'

# %% [markdown]
# ## Function arguments - various types and applications

# %%
# Example 5
# Positional Required argument is demonstrated below

def func_5(age,name):
    print('Your age is:', age)
    print('Your name is:', name)
user_age=input('Enter age')
user_name=input('Enter name')
func_5(user_age,user_name)
func_5(user_name,user_age)  # This function call won't throw an error but at the place of age, name will be displayed. So, 
                            # here argument position matters
# Out:
# Enter age32
# Enter namedeb
# Your age is: 32
# Your name is: deb
# Your age is: deb
# Your name is: 32

# %%
#Example 6
# Keyword argument is demonstrated below

def func_5(age,name):
    print('Your age is:', age)
    print('Your name is:', name)
user_age=input('Enter age')
user_name=input('Enter name')
func_5(age=user_age,name=user_name)
func_5(name=user_name,age=user_age)  # In this function call, we have mentioned the keyword name
# Out:
# Enter age32
# Enter nameDeba
# Your age is: 32
# Your name is: Deba
# Your age is: 32
# Your name is: Deba

# %% [markdown]
# ## Can we have positional and keyword argument call together? If yes, do we have any specific rule regarding that?

# %%
# Example 7
# Here positional and keyword argument are called together. However you can use both together 
#But once keyword argument is written, after that positional can't be written
def func_5(age,name):
    print('Your age is:', age)
    print('Your name is:', name)
user_age=input('Enter age')
user_name=input('Enter name')
func_5(user_age,name=user_name)
func_5(age=user_age,user_name)  #Error Line
# Out:
#   File "<ipython-input-5-10660b7c1a8e>", line 8
#     func_5(age=user_age,user_name)  #Error Line
#                        ^
# SyntaxError: positional argument follows keyword argument

# %%
# Example 8  
#Here it is mixed, but the rule has been followed

def func_5(age,name):
    print('Your age is:', age)
    print('Your name is:', name)
user_age=input('Enter age ')
user_name=input('Enter name ')
func_5(user_age,name=user_name)
# Out:
# Enter age 32
# Enter name Deba
# Your age is: 32
# Your name is: Deba

# %%
# Default Argument 
# It means that you can mention a default value for an argument while defining the function. So, even though you don't pass the
# value for that particular argument while calling the function, it takes the default value. But non-default argument can't be
# written after default argument. Please observe the same error in this code
# Example 9

def func_5(age=20,name):
    print('Your age is:', age)
    print('Your name is:', name)
user_age=input('Enter age')
user_name=input('Enter name')
func_5(name=user_name)
# Out:
#   File "<ipython-input-8-2d8569c57d8c>", line 7
#     def func_5(age=20,name):
#               ^
# SyntaxError: non-default argument follows default argument

# %%
# Example 10
# the below is correct code where it takes the default code.
def func_5(name,age=20):
    print('Your age is:', age)
    print('Your name is:', name)
user_age=input('Enter age ')
user_name=input('Enter name ')
func_5(name=user_name)
# Out:
# Enter age 32
# Enter name Debasis
# Your age is: 20
# Your name is: Debasis

# %%
## Variable Length Arguments. It is shown below we can pass many arguments in case of variable length arguments
# Example 11

def func_6(arg1,arg2,*arg3):   # It means while calling the function you must pass 2 argument and zero or more other arguments
    print(arg1)
    print(arg2)
    print(arg3)
func_6(10,20)
func_6(10,20,30)
func_6(10,20,30,40)
func_6(10)  # Invalid functional as there are two mandatory arguments present
# Out:
# 10
# 20
# ()
# 10
# 20
# (30,)
# 10
# 20
# (30, 40)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-63af31769ec3> in <module>
#       9 func_6(10,20,30)
#      10 func_6(10,20,30,40)
# ---> 11 func_6(10)  # Invalid functional as there are two mandatory arguments present
#
# TypeError: func_6() missing 1 required positional argument: 'arg2'

# %%
# Example 12
# Please check the bug in this code. What is the problem? The problem is that, you should not write any mandatory argument after
# writing variable argument. You can write in one way. For that, check the next code
def func_6(arg1,arg2,*arg3,arg4):  
    print(arg1)
    print(arg2)
    print(arg3)
    print(arg4)
func_6(10,20,30)
func_6(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-bb9096673284> in <module>
#       7     print(arg3)
#       8     print(arg4)
# ----> 9 func_6(10,20,30)
#      10 func_6(10,20,30)
#
# TypeError: func_6() missing 1 required keyword-only argument: 'arg4'

# %%
# Example 13. 
# Here variable length argument and mandatory argument follows a proper order
def func_6(arg1,arg2,*arg3,arg4=50):  
    print(arg1)
    print(arg2)
    print(arg3)
    print(arg4)
func_6(10,20,30)
func_6(10,20,30)
# Out:
# 10
# 20
# (30,)
# 50
# 10
# 20
# (30,)
# 50

# %%
# Example 14
# This is not the write way of coding.There is no point of writing two variable arguments.This is a bug
def func_6(arg1,arg2,*arg3,*arg5):  
    print(arg1)
    print(arg2)
    print(arg3)
    print(arg4)
    print(arg5)
func_6(10,20,30,40)
func_6(10,20,30,60,70,80)
# Out:
#   File "<ipython-input-14-e1518423abb1>", line 3
#     def func_6(arg1,arg2,*arg3,*arg5):
#                                ^
# SyntaxError: invalid syntax

# %%
# Example 15
# Variable keyarguments stored as a dictionary
def func_7(arg1,arg2,*arg3,**keyargs):
    print(arg1)
    print(arg2)
    print(arg3)
    print(str(keyargs))
func_7(10,20,30,40,name='Abhijit',country='India')
# Out:
# 10
# 20
# (30, 40)
# {'name': 'Abhijit', 'country': 'India'}

# %% [markdown]
# ## Local variable vs. global variable, global keyword, memory address, id()

# %%
# Example 1   
# Although x and y are two different variables, it will have same memory addess
x=20
y=20
print(id(x))
print(id(y))
# Out:
# 94175701718656
# 94175701718656

# %%
# Example 2
# But, kindly check for list. The address is not going to be same.
list1=[1,2,3]
list2=[1,2,3]
tuple1=(1,2,3)
list3=list(tuple1)
print(id(list1))
print(id(list2))
print(id(list3))
print(id(tuple1))
# Out:
# 140665969704584
# 140665969702536
# 140665960546696
# 140666031300184

# %%
# Example 3
# Local vs Global Variable

a=100  # This is global variable a
def func_8():
    a=200   # This is local variable a
    print(a)
    print(id(a))  # This is the memory address of local variable a
func_8()
print(a)
print(id(a)) # This is the memory address of global variable a
# Out:
# 200
# 94175701724416
# 100
# 94175701721216

# %%
# Example 4
# Local vs Global Variable
# I want to modify the gloabl variable inside a function. What should I do?
a=100  # This is global variable a
def func_8():
    global a
    a=200   # This is now global variable a
    print(a)
    print(id(a))  # This is the memory address of global variable a
func_8()
print(a)
print(id(a)) # This is the memory address of global variable a
# Out:
# 200
# 94175701724416
# 200
# 94175701724416

# %%
# Example 5
# In this code, by writing global a before the value assignment line, we have made the behaviour of a to be global. So it is
# accessible outside
def func_9():
    global a
    a=199
func_9()
print(a)
# Out:
# 199

# %%
# Example 6
# In this case b acts as a local variable, so not accessible outside
def func_9():
    b=100
func_9()
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a015efcf08a5> in <module>
#       4     b=100
#       5 func_9()
# ----> 6 print(b)
#
# NameError: name 'b' is not defined

# %%
# Example 7
# Check this bug
a=100
def func_10():
    a=200
    print(a)
    print(id(a))
    global a
    a=300
    print(id(a))
func_10()
print(a)
print(id(a))
# Out:
#   File "cell_name", line 11
# SyntaxError: name 'a' is used prior to global declaration

# %%
# the print statement is printed 4 times as the break statement is used.
for i in range(1,5):
    print('Welcome to Edureka',i)
    if(i>=4):
        break
else:
    print('The for loop was successfully executed')
# Out:
# Welcome to Edureka 1
# Welcome to Edureka 2
# Welcome to Edureka 3
# Welcome to Edureka 4
